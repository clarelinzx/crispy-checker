# %%
from harmony_checker import Harmony_checker

file = 'harmony_sample_0'
file_path = f'./data/xml/{file}.xml'
file_output_path = f'./output/{file}_output.xlsx'


hc = Harmony_checker(file_path)
hc.run()
hc.output(file_output_path)
# Out:
# -------------------- df_info  --------------------
# [Required]
# key signature: <music21.key.KeySignature of 3 sharps>
# the pitches altered by this key signature: ['F#', 'C#', 'G#']
# [Optional]
# lecture: None
# question_type: nan
# question_mode: nan
# key_student None is not available. set as None.
# -------------------- df_score --------------------
# [Required]
# VOICES: Index(['S', 'A', 'T', 'B'], dtype='object')
# [Optional]
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# Name: scale degree, dtype: bool
# possible_key_major: A major
# possible_key_minor: f# minor, minor_leading_tone: E#
# The key should be A major
# The student answers None, while key detected should be A major

# %%
hc.y.df_info
# Out:
#   Time signature Key signature Type Mode Key by student Lecture
# 1            2/2             3  NaN  NaN            NaN     NaN

# %%
hc.y.df_score
# Out:
#       S    A    T    B measure scale degree
# 0    A4   E4  C#4   A3       1          NaN
# 1   G#4   E4   B3  G#3       1          NaN
# 2    B4   E4   B3   E3       2          NaN
# 3   C#5  C#4   A3  F#3       2          NaN
# 4    A4  C#4  C#4   A2       3          NaN
# 5   G#4   D4   D4   B2       3          NaN
# 6    E5   B4  G#3   E3       4          NaN
# 7    E5  G#4  G#3  C#3       4          NaN
# 8    E5   E4   A3   A2       5          NaN
# 9    D5  F#4   B3   D3       5          NaN
# 10  C#5   E4  G#3  C#3       6          NaN
# 11  C#5  C#4   E4   A2       6          NaN
# 12   B4   D4  F#4   B2       7          NaN
# 13  G#4   E4  G#4   E3       7          NaN
# 14   A4   A3   E4   A2       8          NaN

# %%
hc.ALL_RESULT
# Out:
#                                     result Voice 1 Voice 2    S    A    T  \
# Level   Place type Place
# Wrong   Vertical   0               和聲方面有問題    None    None   A4   E4  C#4
#                    1               和聲方面有問題    None    None  G#4   E4   B3
#                    2               和聲方面有問題    None    None   B4   E4   B3
#                    3               和聲方面有問題    None    None  C#5  C#4   A3
#                    4               和聲方面有問題    None    None   A4  C#4  C#4
#                    5               和聲方面有問題    None    None  G#4   D4   D4
#                    6               和聲方面有問題    None    None   E5   B4  G#3
#                    6                  音域配置       A       T   E5   B4  G#3
#                    7               和聲方面有問題    None    None   E5  G#4  G#3
#                    8               和聲方面有問題    None    None   E5   E4   A3
#                    9               和聲方面有問題    None    None   D5  F#4   B3
#                    10              和聲方面有問題    None    None  C#5   E4  G#3
#                    11                   交越       A       T  C#5  C#4   E4
#                    11              和聲方面有問題    None    None  C#5  C#4   E4
#                    12                   交越       A       T   B4   D4  F#4
#                    12              和聲方面有問題    None    None   B4   D4  F#4
#                    13                   交越       A       T  G#4   E4  G#4
#                    13              和聲方面有問題    None    None  G#4   E4  G#4
#                    14                   交越       A       T   A4   A3   E4
#                    14              和聲方面有問題    None    None   A4   A3   E4
#         Horizontal (0, 1)            平行一五八       S       B  NaN  NaN  NaN
#                    (2, 3)            平行一五八       S       B  NaN  NaN  NaN
#                    (3, 4)       隱伏八五度(外聲部)       S       B  NaN  NaN  NaN
#                    (4, 5)               越位       A       T  NaN  NaN  NaN
#                    (4, 5)            平行一五八       A       T  NaN  NaN  NaN
#                    (5, 6)               越位       S       A  NaN  NaN  NaN
#                    (5, 6)    單聲部橫向旋律包含增減音程       T    None  NaN  NaN  NaN
#                    (5, 6)         聲部大跳違反原則       A    None  NaN  NaN  NaN
#                    (5, 6)       隱伏八五度(外聲部)       S       B  NaN  NaN  NaN
#                    (6, 7)            平行一五八       A       B  NaN  NaN  NaN
#                    (7, 8)            平行一五八       A       B  NaN  NaN  NaN
#                    (8, 9)            平行一五八       A       T  NaN  NaN  NaN
#                    (9, 10)           平行一五八       S       B  NaN  NaN  NaN
#                    (10, 11)       聲部大跳違反原則       T    None  NaN  NaN  NaN
#                    (11, 12)             越位       A       T  NaN  NaN  NaN
#                    (11, 12)          平行一五八       T       B  NaN  NaN  NaN
#                    (12, 13)             越位       A       T  NaN  NaN  NaN
#                    (13, 14)          平行一五八       A       B  NaN  NaN  NaN
# Warning Vertical   0               和聲方面有問題    None    None   A4   E4  C#4
#                    1               和聲方面有問題    None    None  G#4   E4   B3
#                    2               和聲方面有問題    None    None   B4   E4   B3
#                    3               和聲方面有問題    None    None  C#5  C#4   A3
#                    4               和聲方面有問題    None    None   A4  C#4  C#4
#                    5               和聲方面有問題    None    None  G#4   D4   D4
#                    6               和聲方面有問題    None    None   E5   B4  G#3
#                    7               和聲方面有問題    None    None   E5  G#4  G#3
#                    8               和聲方面有問題    None    None   E5   E4   A3
#                    9               和聲方面有問題    None    None   D5  F#4   B3
#                    10              和聲方面有問題    None    None  C#5   E4  G#3
#                    11              和聲方面有問題    None    None  C#5  C#4   E4
#                    12              和聲方面有問題    None    None   B4   D4  F#4
#                    13              和聲方面有問題    None    None  G#4   E4  G#4
#                    14              和聲方面有問題    None    None   A4   A3   E4
#
#                                B measure scale degree
# Level   Place type Place
# Wrong   Vertical   0          A3       1          NaN
#                    1         G#3       1          NaN
#                    2          E3       2          NaN
#                    3         F#3       2          NaN
#                    4          A2       3          NaN
#                    5          B2       3          NaN
#                    6          E3       4          NaN
#                    6          E3       4          NaN
#                    7         C#3       4          NaN
#                    8          A2       5          NaN
#                    9          D3       5          NaN
#                    10        C#3       6          NaN
#                    11         A2       6          NaN
#                    11         A2       6          NaN
#                    12         B2       7          NaN
#                    12         B2       7          NaN
#                    13         E3       7          NaN
#                    13         E3       7          NaN
#                    14         A2       8          NaN
#                    14         A2       8          NaN
#         Horizontal (0, 1)    NaN     NaN          NaN
#                    (2, 3)    NaN     NaN          NaN
#                    (3, 4)    NaN     NaN          NaN
#                    (4, 5)    NaN     NaN          NaN
#                    (4, 5)    NaN     NaN          NaN
#                    (5, 6)    NaN     NaN          NaN
#                    (5, 6)    NaN     NaN          NaN
#                    (5, 6)    NaN     NaN          NaN
#                    (5, 6)    NaN     NaN          NaN
#                    (6, 7)    NaN     NaN          NaN
#                    (7, 8)    NaN     NaN          NaN
#                    (8, 9)    NaN     NaN          NaN
#                    (9, 10)   NaN     NaN          NaN
#                    (10, 11)  NaN     NaN          NaN
#                    (11, 12)  NaN     NaN          NaN
#                    (11, 12)  NaN     NaN          NaN
#                    (12, 13)  NaN     NaN          NaN
#                    (13, 14)  NaN     NaN          NaN
# Warning Vertical   0          A3       1          NaN
#                    1         G#3       1          NaN
#                    2          E3       2          NaN
#                    3         F#3       2          NaN
#                    4          A2       3          NaN
#                    5          B2       3          NaN
#                    6          E3       4          NaN
#                    7         C#3       4          NaN
#                    8          A2       5          NaN
#                    9          D3       5          NaN
#                    10        C#3       6          NaN
#                    11         A2       6          NaN
#                    12         B2       7          NaN
#                    13         E3       7          NaN
#                    14         A2       8          NaN
